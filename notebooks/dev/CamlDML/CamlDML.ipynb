# %% [markdown]
# # Caml API Usage

# %%
import os
import sys

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

datasets = [
    "partially_linear_simple",
    "fully_heterogenous",
    "partially_linear_constant",
    "dowhy_linear",
]
backends = ["pandas", "pyspark", "polars"]

df_backend = backends[0]
dataset = datasets[3]

# %% [markdown]
# ## Synthetic Data

# %%
from caml.extensions.synthetic_data import (
    make_partially_linear_dataset_simple,
    make_fully_heterogeneous_dataset,
    make_partially_linear_dataset_constant,
    make_dowhy_linear_dataset,
)

if dataset == "partially_linear_simple":
    df, true_cates, true_ate = make_partially_linear_dataset_simple(
        n_obs=5000,
        n_confounders=5,
        dim_heterogeneity=2,
        binary_treatment=True,
        seed=None,
    )
    df["true_cates"] = true_cates
elif dataset == "fully_heterogenous":
    df, true_cates, true_ate = make_fully_heterogeneous_dataset(
        n_obs=5000,
        n_confounders=50,
        theta=4.0,
        seed=None,
    )
    df["true_cates"] = true_cates
elif dataset == "partially_linear_constant":
    df, true_cates, true_ate = make_partially_linear_dataset_constant(
        n_obs=5000,
        ate=4.0,
        n_confounders=5,
        dgp="make_plr_CCDDHNR2018",  # make_plr_turrell2018
        seed=None,
    )
    df["true_cates"] = true_cates
elif dataset == "dowhy_linear":
    df, true_cates, true_ate = make_dowhy_linear_dataset(
        beta=2.0,
        n_obs=5000,
        n_confounders=0,
        n_discrete_confounders=0,
        n_effect_modifiers=4,
        n_discrete_effect_modifiers=4,
        n_treatments=1,
        binary_treatment=True,
        categorical_treatment=False,
        binary_outcome=False,
        seed=0,
    )

    for i in range(1, len(true_cates) + 1):
        if isinstance(true_cates[f"d{i}"], list):
            df[f"true_cate_d{i}_1"] = true_cates[f"d{i}"][0]
            df[f"true_cate_d{i}_2"] = true_cates[f"d{i}"][1]
        else:
            df[f"true_cate_d{i}"] = true_cates[f"d{i}"]


df["uuid"] = df.index

# %%
try:
    import polars as pl
    from pyspark.sql import SparkSession
except ImportError:
    pass

if df_backend == "polars":
    df = pl.from_pandas(df)
    spark = None
elif df_backend == "pandas":
    spark = None
    pass
elif df_backend == "pyspark":
    spark = (
        SparkSession.builder.master("local[1]")
        .appName("local-tests")
        .config("spark.executor.cores", "1")
        .config("spark.executor.instances", "1")
        .config("spark.sql.shuffle.partitions", "1")
        .getOrCreate()
    )
    df = spark.createDataFrame(df)

# %%
# onehot encode X0, X1, X2, and X3 pandas backend
import pandas as pd 

df = pd.get_dummies(df, columns=["X0", "X1", "X2", "X3"],drop_first=True)

# %% [markdown]
# ## Core API

# %% [markdown]
# ### CamlCATE

# %% [markdown]
# #### Class Instantiation

# %%
from caml import CamlCATE

caml = CamlCATE(
    df=df,
    Y="y",
    T="d1",
    X=[c for c in df.columns if "X" in c] + [c for c in df.columns if "W" in c],
    uuid="uuid",
    discrete_treatment=True,
    discrete_outcome=False,
    seed=0,
    verbose=1,
)
# Out:
# [09/23/24 15:17:00] INFO     Logging has been set up.                                                 ]8;id=725110;file:///caml/caml/logging.py\logging.py]8;;\:]8;id=40502;file:///caml/caml/logging.py#51\51]8;;\

# %%
print(caml)
# Out:
# ================== CamlCATE Object ==================
# Data Backend: pandas
# No. of Observations: 5000
# UUID: uuid
# Outcome Variable: y
# Discrete Outcome: False
# Treatment Variable: d1
# Discrete Treatment: True
# Features/Confounders: ['X0_1', 'X0_2', 'X0_3', 'X1_1', 'X1_2', 'X1_3', 'X2_1', 'X2_2', 'X2_3', 'X3_1', 'X3_2', 'X3_3']
# Random Seed: 0

# %% [markdown]
# #### Nuissance Function AutoML

# %%
caml.auto_nuisance_functions(
    flaml_Y_kwargs={"time_budget": 30},
    flaml_T_kwargs={"time_budget": 30},
    use_ray=False,
    use_spark=False,
)
# Out:
# [flaml.automl.logger: 09-23 15:17:02] {1680} INFO - task = regression
# [flaml.automl.logger: 09-23 15:17:02] {1691} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-23 15:17:02] {1789} INFO - Minimizing error metric: mse
# [flaml.automl.logger: 09-23 15:17:02] {1901} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:02] {2345} INFO - Estimated sufficient time budget=631s. Estimated necessary time budget=4s.
# [flaml.automl.logger: 09-23 15:17:02] {2392} INFO -  at 0.1s,	estimator lgbm's best error=15.9359,	best estimator lgbm's best error=15.9359
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:02] {2392} INFO -  at 0.1s,	estimator lgbm's best error=15.8603,	best estimator lgbm's best error=15.8603
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:02] {2392} INFO -  at 0.1s,	estimator lgbm's best error=15.8603,	best estimator lgbm's best error=15.8603
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:02] {2392} INFO -  at 0.2s,	estimator lgbm's best error=15.8603,	best estimator lgbm's best error=15.8603
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:02] {2392} INFO -  at 0.2s,	estimator lgbm's best error=15.5719,	best estimator lgbm's best error=15.5719
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:02] {2392} INFO -  at 0.3s,	estimator xgboost's best error=15.9359,	best estimator lgbm's best error=15.5719
# [flaml.automl.logger: 09-23 15:17:02] {2219} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.4s,	estimator lgbm's best error=15.4743,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.4s,	estimator lgbm's best error=15.4743,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.4s,	estimator lgbm's best error=15.4743,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.5s,	estimator xgboost's best error=15.8815,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.7s,	estimator lgbm's best error=15.4743,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.8s,	estimator extra_tree's best error=15.7641,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 0.9s,	estimator extra_tree's best error=15.7174,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 1.0s,	estimator rf's best error=15.8359,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 1.2s,	estimator rf's best error=15.7424,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 1.3s,	estimator rf's best error=15.7312,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:03] {2392} INFO -  at 1.3s,	estimator lgbm's best error=15.4743,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:03] {2219} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.3s,	estimator xgboost's best error=15.8710,	best estimator lgbm's best error=15.4743
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.4s,	estimator lgbm's best error=15.4531,	best estimator lgbm's best error=15.4531
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.4s,	estimator lgbm's best error=15.3962,	best estimator lgbm's best error=15.3962
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.4s,	estimator lgbm's best error=15.3962,	best estimator lgbm's best error=15.3962
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.5s,	estimator lgbm's best error=15.3962,	best estimator lgbm's best error=15.3962
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.6s,	estimator extra_tree's best error=15.6647,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.7s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.7s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.7s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.8s,	estimator xgboost's best error=15.8710,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 1.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.0s,	estimator extra_tree's best error=15.6551,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.2s,	estimator xgboost's best error=15.8579,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:04] {2392} INFO -  at 2.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:04] {2219} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.5s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.7s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.7s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.8s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 2.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.0s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:05] {2392} INFO -  at 3.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:05] {2219} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.5s,	estimator rf's best error=15.6299,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.7s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 66, current learner rf
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.8s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 3.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 4.0s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 69, current learner rf
# [flaml.automl.logger: 09-23 15:17:06] {2392} INFO -  at 4.2s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:06] {2219} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.3s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 71, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.5s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 73, current learner rf
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.6s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.8s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.9s,	estimator xgboost's best error=15.5514,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 4.9s,	estimator xgboost's best error=15.5514,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 5.0s,	estimator xgboost's best error=15.5514,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 5.1s,	estimator xgboost's best error=15.5514,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 81, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 5.1s,	estimator xgboost's best error=15.5175,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 5.2s,	estimator xgboost's best error=15.4484,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 83, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:07] {2392} INFO -  at 5.2s,	estimator xgboost's best error=15.4484,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:07] {2219} INFO - iteration 84, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.3s,	estimator xgboost's best error=15.4285,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 85, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.4s,	estimator xgboost's best error=15.4285,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 86, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.5s,	estimator xgboost's best error=15.4285,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 87, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 89, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.8s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 90, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 91, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 5.9s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 92, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 6.0s,	estimator xgboost's best error=15.4285,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 93, current learner rf
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 6.1s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 94, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:08] {2392} INFO -  at 6.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:08] {2219} INFO - iteration 95, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 6.3s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 96, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 6.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 97, current learner rf
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 6.6s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 6.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 99, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 6.7s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 100, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 6.8s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 101, current learner rf
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 7.0s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 102, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:09] {2392} INFO -  at 7.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:09] {2219} INFO - iteration 103, current learner rf
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 7.3s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 104, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 7.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 105, current learner rf
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 7.5s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 7.7s,	estimator extra_tree's best error=15.5690,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 107, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 7.7s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 108, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 7.8s,	estimator extra_tree's best error=15.5556,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 109, current learner rf
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 8.0s,	estimator rf's best error=15.5533,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 110, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 8.0s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 111, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 8.1s,	estimator xgboost's best error=15.4285,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 112, current learner rf
# [flaml.automl.logger: 09-23 15:17:10] {2392} INFO -  at 8.2s,	estimator rf's best error=15.5515,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:10] {2219} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.4s,	estimator extra_tree's best error=15.5556,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 114, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 115, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 116, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.7s,	estimator xgboost's best error=15.4285,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 117, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.8s,	estimator xgboost's best error=15.4091,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 118, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 119, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.9s,	estimator xgboost's best error=15.4065,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 120, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 8.9s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 121, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.0s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 122, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.0s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 123, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.1s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 124, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 125, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 127, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:11] {2392} INFO -  at 9.3s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:11] {2219} INFO - iteration 128, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.3s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 129, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.4s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 130, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.4s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 131, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.4s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 132, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 133, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.7s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 134, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.7s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 135, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.7s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 136, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.8s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 137, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 138, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 9.9s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 139, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 10.0s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 140, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 10.1s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 141, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 10.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 142, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 10.2s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 143, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:12] {2392} INFO -  at 10.3s,	estimator xgboost's best error=15.3706,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:12] {2219} INFO - iteration 144, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.3s,	estimator xgboost's best error=15.3643,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 145, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 146, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 147, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 148, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 149, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 150, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 151, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 152, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 153, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 154, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 155, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.8s,	estimator extra_tree's best error=15.5490,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 156, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 157, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.8s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 158, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 159, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 10.9s,	estimator xgboost's best error=15.3643,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 160, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 11.0s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 161, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 11.0s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 162, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 11.1s,	estimator extra_tree's best error=15.5490,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 163, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:13] {2392} INFO -  at 11.3s,	estimator xgboost's best error=15.3643,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:13] {2219} INFO - iteration 164, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 165, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 166, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 167, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.4s,	estimator xgboost's best error=15.3643,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 168, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 169, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 170, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.5s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 171, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 172, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 173, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 174, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.6s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 175, current learner extra_tree
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.9s,	estimator extra_tree's best error=15.5490,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 176, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 177, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 11.9s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 178, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.0s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 179, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.0s,	estimator xgboost's best error=15.3643,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 180, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 181, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 182, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 183, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 184, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 185, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.2s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 186, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:14] {2392} INFO -  at 12.3s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:14] {2219} INFO - iteration 187, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 12.3s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 188, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 12.4s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 189, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 12.5s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 190, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 12.7s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 191, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 12.8s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 192, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 12.9s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 193, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:15] {2392} INFO -  at 13.2s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:15] {2219} INFO - iteration 194, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 13.3s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 195, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 13.4s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 196, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 13.5s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 197, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 13.9s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 198, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 14.0s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 199, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 14.1s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 200, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 14.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 201, current learner lgbm
# [flaml.automl.logger: 09-23 15:17:16] {2392} INFO -  at 14.1s,	estimator lgbm's best error=15.3386,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:16] {2219} INFO - iteration 202, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:17] {2392} INFO -  at 14.3s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:17] {2219} INFO - iteration 203, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:17] {2392} INFO -  at 14.4s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:17] {2219} INFO - iteration 204, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:17] {2392} INFO -  at 14.7s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# [flaml.automl.logger: 09-23 15:17:17] {2219} INFO - iteration 205, current learner xgboost
# [flaml.automl.logger: 09-23 15:17:17] {2392} INFO -  at 14.7s,	estimator xgboost's best error=15.3452,	best estimator lgbm's best error=15.3386
# ...
# [flaml.automl.logger: 09-23 15:18:28] {2219} INFO - iteration 353, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:28] {2392} INFO -  at 25.5s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:28] {2219} INFO - iteration 354, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:28] {2392} INFO -  at 25.6s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:28] {2219} INFO - iteration 355, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:28] {2392} INFO -  at 25.6s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:28] {2219} INFO - iteration 356, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:28] {2392} INFO -  at 25.7s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:28] {2219} INFO - iteration 357, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:28] {2392} INFO -  at 25.9s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:28] {2219} INFO - iteration 358, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.3s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 359, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.4s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 360, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.7s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 361, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.8s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 362, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.8s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 363, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.8s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 364, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 26.9s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 365, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:29] {2392} INFO -  at 27.1s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:29] {2219} INFO - iteration 366, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.1s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 367, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.2s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 368, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.2s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 369, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 370, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 371, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 372, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 373, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.4s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 374, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.4s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 375, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.7s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 376, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.7s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 377, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.7s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 378, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 27.8s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 379, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 28.0s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 380, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 28.0s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 381, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 28.0s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 382, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 28.1s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 383, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:30] {2392} INFO -  at 28.1s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:30] {2219} INFO - iteration 384, current learner rf
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.2s,	estimator rf's best error=0.6934,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 385, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 386, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 387, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.3s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 388, current learner rf
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.5s,	estimator rf's best error=0.6934,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 389, current learner xgboost
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.6s,	estimator xgboost's best error=0.6930,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 390, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.7s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 391, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.8s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 392, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.8s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 393, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.9s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 394, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 28.9s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 395, current learner rf
# [flaml.automl.logger: 09-23 15:18:31] {2392} INFO -  at 29.1s,	estimator rf's best error=0.6934,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:31] {2219} INFO - iteration 396, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.2s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 397, current learner extra_tree
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.3s,	estimator extra_tree's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 398, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.4s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 399, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.5s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 400, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.5s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 401, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.5s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 402, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.6s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 403, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.6s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 404, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.6s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 405, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.7s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 406, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.7s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 407, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.8s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 408, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.9s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 409, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.9s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 410, current learner xgb_limitdepth
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 29.9s,	estimator xgb_limitdepth's best error=0.6929,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2219} INFO - iteration 411, current learner lgbm
# [flaml.automl.logger: 09-23 15:18:32] {2392} INFO -  at 30.0s,	estimator lgbm's best error=0.6931,	best estimator xgb_limitdepth's best error=0.6929
# [flaml.automl.logger: 09-23 15:18:32] {2628} INFO - retrain xgb_limitdepth for 0.0s
# [flaml.automl.logger: 09-23 15:18:32] {2631} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.8164277976029399, colsample_bynode=None,
#               colsample_bytree=0.8649818146817685, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.10823741165018076,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=128.0, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=4, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 09-23 15:18:32] {1931} INFO - fit succeeded
# [flaml.automl.logger: 09-23 15:18:32] {1932} INFO - Time taken to find the best model: 16.505903244018555

# %% [markdown]
# #### Fit and ensemble CATE models

# %%
caml.fit_validator(
    subset_cate_models=[
        "LinearDML",
        # "NonParamDML",
        # "DML-Lasso3d",
        # "CausalForestDML",
        # "XLearner",
        # "DomainAdaptationLearner",
        # "SLearner",
        # "TLearner",
        # "DRLearner",
        # "LinearDRLearner",
        # "ForestDRLearner",
    ],
    rscorer_kwargs={},
    use_ray=False,
    ray_remote_func_options_kwargs={},
    sample_fraction=1,
    n_jobs=-1,
)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# [09/23/24 15:18:35] INFO     Ensemble Estimator RScore: 0.5994649776821798                             ]8;id=818961;file:///caml/caml/core/cate.py\cate.py]8;;\:]8;id=665064;file:///caml/caml/core/cate.py#1033\1033]8;;\
#                     INFO     Inidividual Estimator RScores: {'LinearDML': 0.5994649776821798}          ]8;id=103895;file:///caml/caml/core/cate.py\cate.py]8;;\:]8;id=719082;file:///caml/caml/core/cate.py#1034\1034]8;;\
#                     INFO     The best estimator is greater than the ensemble estimator. Returning that ]8;id=254488;file:///caml/caml/core/cate.py\cate.py]8;;\:]8;id=676607;file:///caml/caml/core/cate.py#1046\1046]8;;\
#                              individual estimator: <econml.dml.dml.LinearDML object at 0x7fd4e46210f0>

# %%
model_final.summary()
# Out:
# <class 'econml.utilities.Summary'>
# """
#                    Coefficient Results
# ==========================================================
#      point_estimate stderr zstat  pvalue ci_lower ci_upper
# ----------------------------------------------------------
# X0_1           0.88  0.082 10.723    0.0    0.719     1.04
# X0_2          1.602  0.081 19.761    0.0    1.443    1.761
# X0_3           2.27  0.091 24.947    0.0    2.092    2.448
# X1_1          0.526  0.083  6.361    0.0    0.364    0.688
# X1_2          1.247  0.085 14.722    0.0    1.081    1.413
# X1_3          1.787  0.087  20.54    0.0    1.616    1.957
# X2_1          0.967  0.078 12.446    0.0    0.815     1.12
# X2_2          2.122  0.088 24.124    0.0     1.95    2.295
# X2_3          3.343  0.083 40.416    0.0    3.181    3.505
# X3_1           1.36  0.084 16.246    0.0    1.196    1.524
# X3_2          2.521  0.086 29.211    0.0    2.352     2.69
# X3_3          3.708  0.094 39.322    0.0    3.523    3.893
#                        CATE Intercept Results
# ====================================================================
#                point_estimate stderr zstat  pvalue ci_lower ci_upper
# --------------------------------------------------------------------
# cate_intercept          1.866  0.146 12.801    0.0     1.58    2.152
# --------------------------------------------------------------------
#
# <sub>A linear parametric conditional average treatment effect (CATE) model was fitted:
# $Y = \Theta(X)\cdot T + g(X, W) + \epsilon$
# where for every outcome $i$ and treatment $j$ the CATE $\Theta_{ij}(X)$ has the form:
# $\Theta_{ij}(X) = X' coef_{ij} + cate\_intercept_{ij}$
# Coefficient Results table portrays the $coef_{ij}$ parameter vector for each outcome $i$ and treatment $j$. Intercept Results table portrays the $cate\_intercept_{ij}$ parameter.</sub>
# """

# %%
model_final.ate_inference(caml._X)
# Out:
# <table class="simpletable">
# <caption>Uncertainty of Mean Point Estimate</caption>
# <tr>
#   <th>mean_point</th> <th>stderr_mean</th>  <th>zstat</th>  <th>pvalue</th> <th>ci_mean_lower</th> <th>ci_mean_upper</th>
# </tr>
# <tr>
#      <td>7.449</td>      <td>0.029</td>    <td>253.606</td>   <td>0.0</td>      <td>7.391</td>         <td>7.507</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Distribution of Point Estimate</caption>
# <tr>
#   <th>std_point</th> <th>pct_point_lower</th> <th>pct_point_upper</th>
# </tr>
# <tr>
#     <td>2.17</td>         <td>3.271</td>          <td>11.712</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Total Variance of Point Estimate</caption>
# <tr>
#   <th>stderr_point</th> <th>ci_point_lower</th> <th>ci_point_upper</th>
# </tr>
# <tr>
#       <td>2.17</td>          <td>3.281</td>         <td>11.647</td>
# </tr>
# </table>

# %%
true_ate
# Out:
# {'d1': 7.499120156616214}

# %%
from econml.dml import LinearDML

model_final = LinearDML(
    model_y=caml.model_Y_X,
    model_t=caml.model_T_X,
    discrete_treatment=True,
    discrete_outcome=False,
    cv=3,
)

model_final.fit(Y=caml._Y.execute().to_numpy().ravel(), T=caml._T.execute(),X=caml._X.execute(),cache_values=True)

# %%
model_final.summary()
# Out:
# <class 'econml.utilities.Summary'>
# """
#                    Coefficient Results
# ==========================================================
#      point_estimate stderr zstat  pvalue ci_lower ci_upper
# ----------------------------------------------------------
# X0_1          0.836  0.065 12.927    0.0    0.709    0.962
# X0_2          1.599  0.064 24.813    0.0    1.473    1.725
# X0_3          2.242  0.071 31.445    0.0    2.102    2.381
# X1_1          0.527  0.064  8.234    0.0    0.402    0.653
# X1_2          1.144  0.065 17.638    0.0    1.017    1.272
# X1_3          1.724  0.069  25.01    0.0    1.589    1.859
# X2_1          1.069  0.064 16.661    0.0    0.943    1.195
# X2_2          2.163  0.067 32.094    0.0    2.031    2.295
# X2_3           3.34  0.064 52.023    0.0    3.214    3.465
# X3_1          1.291  0.064 20.022    0.0    1.165    1.418
# X3_2           2.42  0.069 35.282    0.0    2.285    2.554
# X3_3          3.577  0.071 50.171    0.0    3.437    3.717
#                        CATE Intercept Results
# ====================================================================
#                point_estimate stderr zstat  pvalue ci_lower ci_upper
# --------------------------------------------------------------------
# cate_intercept          2.006  0.114 17.636    0.0    1.783    2.229
# --------------------------------------------------------------------
#
# <sub>A linear parametric conditional average treatment effect (CATE) model was fitted:
# $Y = \Theta(X)\cdot T + g(X, W) + \epsilon$
# where for every outcome $i$ and treatment $j$ the CATE $\Theta_{ij}(X)$ has the form:
# $\Theta_{ij}(X) = X' coef_{ij} + cate\_intercept_{ij}$
# Coefficient Results table portrays the $coef_{ij}$ parameter vector for each outcome $i$ and treatment $j$. Intercept Results table portrays the $cate\_intercept_{ij}$ parameter.</sub>
# """

# %%
model_final.ate_inference(X=df[caml.X])
# Out:
# <table class="simpletable">
# <caption>Uncertainty of Mean Point Estimate</caption>
# <tr>
#   <th>mean_point</th> <th>stderr_mean</th>  <th>zstat</th>  <th>pvalue</th> <th>ci_mean_lower</th> <th>ci_mean_upper</th>
# </tr>
# <tr>
#      <td>7.489</td>      <td>0.023</td>    <td>327.343</td>   <td>0.0</td>      <td>7.444</td>         <td>7.534</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Distribution of Point Estimate</caption>
# <tr>
#   <th>std_point</th> <th>pct_point_lower</th> <th>pct_point_upper</th>
# </tr>
# <tr>
#     <td>2.121</td>        <td>3.369</td>          <td>11.666</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Total Variance of Point Estimate</caption>
# <tr>
#   <th>stderr_point</th> <th>ci_point_lower</th> <th>ci_point_upper</th>
# </tr>
# <tr>
#       <td>2.121</td>         <td>3.405</td>         <td>11.588</td>
# </tr>
# </table>

# %%
model_final.ate_inference(X=df[df['X2_2']==1][caml.X])
# Out:
# <table class="simpletable">
# <caption>Uncertainty of Mean Point Estimate</caption>
# <tr>
#   <th>mean_point</th> <th>stderr_mean</th>  <th>zstat</th>  <th>pvalue</th> <th>ci_mean_lower</th> <th>ci_mean_upper</th>
# </tr>
# <tr>
#      <td>7.982</td>      <td>0.048</td>    <td>166.065</td>   <td>0.0</td>      <td>7.888</td>         <td>8.076</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Distribution of Point Estimate</caption>
# <tr>
#   <th>std_point</th> <th>pct_point_lower</th> <th>pct_point_upper</th>
# </tr>
# <tr>
#     <td>1.714</td>        <td>4.696</td>          <td>11.132</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Total Variance of Point Estimate</caption>
# <tr>
#   <th>stderr_point</th> <th>ci_point_lower</th> <th>ci_point_upper</th>
# </tr>
# <tr>
#       <td>1.715</td>         <td>4.597</td>         <td>11.152</td>
# </tr>
# </table>

# %%
df['y_resid']= model_final.residuals_[0]
df['T_resid']= model_final.residuals_[1]

# %%
from statsmodels.formula.api import ols

model = ols("y_resid ~ -1 + T_resid", data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                y_resid   R-squared (uncentered):                   0.888
# Model:                            OLS   Adj. R-squared (uncentered):              0.887
# Method:                 Least Squares   F-statistic:                          3.944e+04
# Date:                Mon, 23 Sep 2024   Prob (F-statistic):                        0.00
# Time:                        15:28:37   Log-Likelihood:                         -8531.3
# No. Observations:                5000   AIC:                                  1.706e+04
# Df Residuals:                    4999   BIC:                                  1.707e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# T_resid        7.4880      0.038    198.589      0.000       7.414       7.562
# ==============================================================================
# Omnibus:                      102.629   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              165.410
# Skew:                          -0.194   Prob(JB):                     1.21e-36
# Kurtosis:                       3.802   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.formula.api import ols

model = ols("y_resid ~ -1 + T_resid", data=df[df['X2_2']==1][['y_resid','T_resid']]).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                y_resid   R-squared (uncentered):                   0.919
# Model:                            OLS   Adj. R-squared (uncentered):              0.919
# Method:                 Least Squares   F-statistic:                          1.417e+04
# Date:                Mon, 23 Sep 2024   Prob (F-statistic):                        0.00
# Time:                        15:25:47   Log-Likelihood:                         -1985.0
# No. Observations:                1250   AIC:                                      3972.
# Df Residuals:                    1249   BIC:                                      3977.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# T_resid        7.9780      0.067    119.022      0.000       7.846       8.110
# ==============================================================================
# Omnibus:                       47.854   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              129.163
# Skew:                          -0.093   Prob(JB):                     8.97e-29
# Kurtosis:                       4.564   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### CATE Validation

# %%
validation_results = caml.validate(estimator=None, print_full_report=True)

# %% [markdown]
# #### Refit best estimator on full dataset

# %%
caml.fit_final()

# %%
caml.final_estimator

# %% [markdown]
# #### Predict CATEs

# %%
## "Out of sample" predictions

df_predictions = caml.predict(
    out_of_sample_df=df,
    out_of_sample_uuid="uuid",
    return_predictions=False,
    join_predictions=True,
)

if df_backend == "pyspark":
    df_predictions.show()
else:
    print(df_predictions)

# %%
## Append to internal dataframe

caml.predict(
    out_of_sample_df=None,
    out_of_sample_uuid=None,
    join_predictions=True,
    return_predictions=False,
)

caml.dataframe

# %% [markdown]
# #### CATE Rank Ordering

# %%
## "Out of sample" predictions

df_rank_ordered = caml.rank_order(
    out_of_sample_df=df_predictions,
    return_rank_order=False,
    join_rank_order=True,
    treatment_category=1,
)

df_rank_ordered

# %%
## Append to internal dataframe

caml.rank_order(
    out_of_sample_df=None,
    return_rank_order=False,
    join_rank_order=True,
    treatment_category=1,
)

caml.dataframe

# %% [markdown]
# #### CATE Visualization/Summary

# %%
cate_summary = caml.summarize(out_of_sample_df=df_rank_ordered, treatment_category=1)

cate_summary

# %%
cate_summary = caml.summarize(out_of_sample_df=None, treatment_category=1)

cate_summary

# %%
true_ate

# %% [markdown]
# #### Access my dataframe, estimator object, and get string representation of class

# %%
caml.dataframe

# %%
from econml.score import EnsembleCateEstimator

# Use this estimator object as pickled object for optimized inference
final_estimator = caml.final_estimator

if isinstance(final_estimator, EnsembleCateEstimator):
    for model in final_estimator._cate_models:
        print(model)
        print(model._input_names)
else:
    print(final_estimator)
    print(final_estimator._input_names)

# %%
print(caml)

# %% [markdown]
# # Plots

# %%
from caml.extensions.plots import (cate_histogram_plot, 
                                   cate_true_vs_estimated_plot, 
                                   cate_line_plot)

# %%
cate_true_vs_estimated_plot(true_cates=caml.dataframe['true_cate_d1'],estimated_cates=caml.dataframe['cate_predictions_1'])

# %%
cate_histogram_plot(estimated_cates=caml.dataframe['cate_predictions_1'])

# %%
cate_histogram_plot(estimated_cates=caml.dataframe['cate_predictions_1'],true_cates=caml.dataframe['true_cate_d1'])

# %%
cate_line_plot(estimated_cates=caml.dataframe['cate_predictions_1'],window=30)

# %%
cate_line_plot(estimated_cates=caml.dataframe['cate_predictions_1'],true_cates=caml.dataframe['true_cate_d1'],window=30)
